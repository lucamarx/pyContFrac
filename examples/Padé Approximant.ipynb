# %% [markdown]
# Padé Approximant
# ===============

# %%
# %matplotlib notebook

import math
import numpy as np
import matplotlib.pyplot as plt

from math import factorial, pi
from contfrac.pade import PadeApprox

# %% [markdown]
# Sine Approximant
# --------------------------

# %%
def sin_taylor():
    "sine Taylor coefficients"
    n = 0
    while True:
        if n%2 == 0:
            yield 0
        elif (n//2)%2 == 0:
            yield 1 / factorial(n)
        else:
            yield -1 / factorial(n)
        n += 1

# %%
sin_app = PadeApprox(8, 8, sin_taylor())
sin_app
# Out:
# PadeApprox(8, 8)

# %%
xs = np.linspace(0, 2*pi, 100)

plt.figure()

plt.plot(xs, np.sin(xs), label="sin")
plt.plot(xs, [sin_app(x) for x in xs], label="Padé")

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Cosine Approximant
# -----------------------------

# %%
def cos_taylor():
    "cosine Taylor coefficients"
    n = 0
    while True:
        if n%2 != 0:
            yield 0
        elif (n//2)%2 == 0:
            yield 1 / factorial(n)
        else:
            yield -1 / factorial(n)
        n += 1

# %%
cos_app = PadeApprox(8, 8, cos_taylor())
cos_app
# Out:
# PadeApprox(8, 8)

# %%
xs = np.linspace(0, 2*pi, 100)

plt.figure()

plt.plot(xs, np.cos(xs), label="cos")
plt.plot(xs, [cos_app(x) for x in xs], label="Padé")

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Page 5 Example
# -----------------------
#
# This example is found at page 5 of
#
# P.G.-M. George, A. Baker Jr., Padé Approximants, Vol.50 (Cambridge University Press, 1996).

# %%
def f(x):
    return math.sqrt((1+x/2)/(1 + 2*x))

f_taylor = [1, -3/4, 39/32]

# %%
f_app = PadeApprox(1, 1, f_taylor)
f_app
# Out:
# PadeApprox(1, 1)

# %%
xs = np.linspace(0, 4, 100)

plt.figure()

plt.plot(xs, [f(x) for x in xs], label="f")
plt.plot(xs, [f_app(x) for x in xs], label="Padé")

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Exponential
# -----------------

# %%
def exp_taylor():
    "exponential Taylor coefficients"
    n = 0
    while True:
        yield 1 / math.factorial(n)
        n += 1

# %%
exp_app = PadeApprox(10, 10, exp_taylor())
exp_app
# Out:
# PadeApprox(10, 10)

# %%
xs = np.linspace(0, 10, 100)

plt.figure()

plt.plot(xs, [math.exp(x) for x in xs], label="exp")
plt.plot(xs, [exp_app(x) for x in xs], label="Padé")

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
